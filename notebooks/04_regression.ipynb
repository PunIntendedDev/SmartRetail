# %% [markdown]
# # Phase 2: Supervised Learning (Regression)
# This notebook trains and compares Linear Regression and MLPRegressor to predict total monetary future spend on the next quarter (Months 10-12) utilizing Months 1-9 customer behaviors. Serializes the best regressor to be loaded as the RL environment's simulator.

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

# %%
from src.regression import train_regression
train_regression()
