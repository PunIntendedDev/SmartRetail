# %% [markdown]
# # Phase 1: Dimensionality Reduction (PCA and LDA)
# This notebook standardizes features, fits PCA and LDA models strictly on the training split under leakage-free constraints, transforms validation/test datasets, and displays principal component explained variances.

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

# %%
from src.dimensionality_reduction import perform_dimensionality_reduction
perform_dimensionality_reduction()
