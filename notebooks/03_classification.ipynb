# %% [markdown]
# # Phase 2: Supervised Learning (Classification)
# This notebook trains and compares Logistic Regression (with cross-validated hyperparameter tuning) and MLPClassifier across the raw, PCA, and LDA feature spaces, scoring on validation splits and outputting test set confusion/ROC curves.

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

# %%
from src.classification import train_classification
train_classification()
