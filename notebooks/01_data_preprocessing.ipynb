# %% [markdown]
# # Phase 0: Data Preprocessing & Cleaning
# This notebook runs the cleaning pipeline on the raw Online Retail transactional database from UCI, extracts customer-level features (Months 1-9), determines the target continuous future spend variable (Months 10-12) to prevent data leakage, and saves the train/validation/test splits.

# %%
# Fix directory issues if running from notebooks subfolder
import os
import sys
sys.path.append(os.path.abspath('..'))

# %%
from src.preprocessing import process_data
process_data()
